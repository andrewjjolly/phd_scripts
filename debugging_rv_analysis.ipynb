# %%
from astropy.io import fits
import wobble
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /apps/tensorflow/1.14-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /apps/tensorflow/1.14-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /apps/tensorflow/1.14-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
DATA_DIR = '/srv/scratch/astro/z5345592/testing/data/tess_toi/'
TOI_NAME = '4507_01'

# %%
for sp_file in Path(DATA_DIR).rglob('*e2ds*'):
    print(sp_file)
# Out:
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-09T14:16:06.654_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-10T07:45:13.466_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-16T19:32:34.331_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-17T08:05:59.385_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-20T19:24:58.676_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-21T08:00:43.838_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-24T21:21:42.610_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-25T07:35:29.254_e2ds_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-11-16T04:24:22.578_e2ds_A.fits
# ...

# %%
for sp_file in Path(DATA_DIR).rglob('*wave*'):
    print(sp_file)
# Out:
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-09T14:16:06.654_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-16T19:32:34.331_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-20T19:24:58.676_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-24T21:21:42.610_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-11-17T20:43:46.445_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-11-22T20:50:23.567_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-12-14T12:50:18.985_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2020-01-03T19:30:17.465_wave_A.fits
# /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2020-01-22T17:13:04.405_wave_A.fits
# ...

# %%
sp_file = fits.open('/srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-09T14:16:06.654_e2ds_A.fits')

# %%
sp_file

# %%
plt.plot(sp_file[0].data)
# Out:
# ...
#  ...]

# %%
sp = fits.open(sp_file)

# %%
sp.info()
# Out:
# Filename: /srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-11-15T19:22:58.512_wave_A.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    2859   (4096, 72)   float32

# %%
sp[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                   72 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'TEST    '                    / European Southern Observatory
# DATE    = '2019-11-15T19:23:40.414'     / UT date when this file was written
# TELESCOP= 'ESO-3P6 '                    / ESO Telescope Name
# INSTRUME= 'HARPS   '                    / Instrument used.
# OBJECT  = 'WAVE,WAVE,THAR2'    / Original target.
# EXPTIME =              39.9980          / Total integration time
# ...

# %%
ccf_filename = '/srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-09T14:16:06.654_e2ds_A.fits'

# %%
ccf = fits.open(ccf_filename)

# %%
ccf[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                   72 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'TEST    '                    / European Southern Observatory
# DATE    = '2019-10-09T14:16:48.397'     / UT date when this file was written
# TELESCOP= 'ESO-3P6 '                    / ESO Telescope Name
# INSTRUME= 'HARPS   '                    / Instrument used.
# OBJECT  = 'WAVE,WAVE,THAR2'    / Original target.
# RA      =           164.230111          / 10:56:55.2 RA (J2000) pointing (deg)
# ...

# %%
spec_file = '/srv/scratch/astro/z5345592/testing/data/tess_toi/4507_01/HARPS.2019-10-10T07:45:13.466_e2ds_A.fits'

# %%
spec_file = fits.open(spec_file)

# %%
spec_file[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                   72 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'TEST    '                    / European Southern Observatory
# DATE    = '2019-10-10T08:05:15.352'     / UT date when this file was written
# TELESCOP= 'ESO-3P6 '                    / ESO Telescope Name
# INSTRUME= 'HARPS   '                    / Instrument used.
# OBJECT  = 'TIC179582003'       / Original target.
# RA      =            80.440095          / 05:21:45.6 RA (J2000) pointing (deg)
# ...
